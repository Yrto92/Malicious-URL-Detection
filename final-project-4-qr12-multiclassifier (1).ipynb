# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in ./python-env/lib/python3.6/site-packages (2.6.2)
# Requirement already satisfied: h5py~=3.1.0 in ./python-env/lib/python3.6/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: clang~=5.0 in ./python-env/lib/python3.6/site-packages (from tensorflow) (5.0)
# Requirement already satisfied: google-pasta~=0.2 in ./python-env/lib/python3.6/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.7,>=2.6.0 in ./python-env/lib/python3.6/site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: tensorboard<2.7,>=2.6.0 in ./python-env/lib/python3.6/site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: wheel~=0.35 in ./python-env/lib/python3.6/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: protobuf>=3.9.2 in ./python-env/lib/python3.6/site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: wrapt~=1.12.1 in ./python-env/lib/python3.6/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: flatbuffers~=1.12.0 in ./python-env/lib/python3.6/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: gast==0.4.0 in ./python-env/lib/python3.6/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in ./python-env/lib/python3.6/site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: absl-py~=0.10 in ./python-env/lib/python3.6/site-packages (from tensorflow) (0.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in ./python-env/lib/python3.6/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in ./python-env/lib/python3.6/site-packages (from tensorflow) (1.47.0)
# Requirement already satisfied: six~=1.15.0 in ./python-env/lib/python3.6/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: termcolor~=1.1.0 in ./python-env/lib/python3.6/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in ./python-env/lib/python3.6/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: keras<2.7,>=2.6.0 in ./python-env/lib/python3.6/site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in ./python-env/lib/python3.6/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: numpy~=1.19.2 in ./python-env/lib/python3.6/site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: cached-property in ./python-env/lib/python3.6/site-packages (from h5py~=3.1.0->tensorflow) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in ./python-env/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in ./python-env/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (2.0.3)
# Requirement already satisfied: setuptools>=41.0.0 in ./python-env/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (59.6.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in ./python-env/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in ./python-env/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in ./python-env/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in ./python-env/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in ./python-env/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (3.3.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./python-env/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in ./python-env/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./python-env/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./python-env/lib/python3.6/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in ./python-env/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (4.8.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./python-env/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./python-env/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in ./python-env/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./python-env/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2021.10.8)
# Requirement already satisfied: dataclasses in ./python-env/lib/python3.6/site-packages (from werkzeug>=0.11.15->tensorboard<2.7,>=2.6.0->tensorflow) (0.8)
# Requirement already satisfied: zipp>=0.5 in ./python-env/lib/python3.6/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in ./python-env/lib/python3.6/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in ./python-env/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow) (3.2.0)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in ./python-env/lib/python3.6/site-packages (4.63.0)
# Requirement already satisfied: importlib-resources in ./python-env/lib/python3.6/site-packages (from tqdm) (5.4.0)
# Requirement already satisfied: zipp>=3.1.0 in ./python-env/lib/python3.6/site-packages (from importlib-resources->tqdm) (3.6.0)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from graphviz import Digraph, Source
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Model
import PIL
from PIL import Image, ImageOps
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA

# %%
version = 12
folder = f"/Users/yaeerk/Documents/NAYA/FinalProject/QRcode{version}"
    
sub_folders = ("benign", "malware", "defacement", "phishing")
dataset_max_size = 30000
random_state = 43021
train_size = 0.8
epochs = 25
batch_size = 128
steps_per_epoch = dataset_max_size // batch_size

filename = f"{dataset_max_size}-{train_size}-{epochs}-{steps_per_epoch}-{version}"
save_path = "/tmp/qrcode/"

# %%
if(version == 4):
    image_size = (33, 33)
elif(version == 5):
    image_size = (37, 37)
elif(version == 6):
    image_size = (41, 41)
elif(version == 12):
    image_size = (65, 65)
else:
    image_size = (36, 36)

# %%
#https://www.kaggle.com/datasets/samahsadiq/benign-and-malicious-qr-codes

#load the dataset

try:

    #raise Exception("load files even if exists") #force reading the dataset

    #read the images
    with open(save_path + 'multi-qr-image-' + str(dataset_max_size), 'rb') as f:
        X = np.load(f)

    #read the labels
    with open(save_path + 'multi-qr-label-' + str(dataset_max_size), 'rb') as f:
        y = np.load(f)

    print(f"dataset was loaded")

except:

    X, y = [], []
    
    for p, sub_folder in enumerate(sub_folders):

        X_subfolder, y_subfolder = [], []

        path = folder + "/" + sub_folder
        image_filenames = [filename for filename in os.listdir(path) if("png" in filename)]

        if(len(image_filenames) > dataset_max_size):        
            image_filenames = image_filenames[:dataset_max_size]

        for image_filename in tqdm(image_filenames, desc = "Loading " +  sub_folder, ncols = 110):

            try:
                m = Image.open(path + "/" + image_filename)

                #resize to predefined size
                m = m.resize(image_size, resample = PIL.Image.BICUBIC)

                #convert to gray scale
                m = ImageOps.grayscale(m)

                #convert to numpy array and do not rescale, save it in byte (smaller size on disk)
                n = np.array(m.getdata()).reshape(image_size[0], image_size[1], 1) / 255.0

                #append to datasets
                X_subfolder.append(n)

                a = np.zeros(4)
                a[p] = 1
                y_subfolder.append(a)

            except:
                print(f"count not load: {image_filenames}")
                    
        #rescale
        X.extend(X_subfolder)
        y.extend(y_subfolder)
        
    X = np.array(X)
    y = np.array(y)

    try:
        #save the images
        with open(save_path + 'multi-qr-image-' + str(dataset_max_size), 'wb') as f:
            np.save(f, X)

        #save the labels
        with open(save_path + 'multi-qr-label-' + str(dataset_max_size), 'wb') as f:
            np.save(f, y)

    except:
        print("unable to save images & labels")
# Out:
# Loading benign: 100%|██████████████████████████████████████████████████| 30000/30000 [00:43<00:00, 682.20it/s]
# Loading malware: 100%|█████████████████████████████████████████████████| 30000/30000 [00:43<00:00, 685.63it/s]
# Loading defacement: 100%|██████████████████████████████████████████████| 30000/30000 [00:42<00:00, 698.22it/s]
# Loading phishing: 100%|████████████████████████████████████████████████| 30000/30000 [00:43<00:00, 696.62it/s]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, random_state = random_state)

# %%
#visualize the input data
fig = plt.figure(figsize = (15, 15))
for i in range(25):
    ax = plt.subplot(5, 5, i + 1)
    plt.imshow(X_test[i], cmap = 'binary')
    for j in range(4):
        if(y_test[i][j] > 0):
            plt.title(sub_folders[j])
            break
    plt.axis("off")
  
fig.suptitle('multi-classifier input dataset')
plt.savefig(save_path + "multi-classifier-" + filename + "-visualization.png")
plt.show()

# %%
#typical categorial classifier
multiclassifier = tf.keras.Sequential([

    tf.keras.layers.Input(shape = (image_size[0], image_size[1], 1)),

    tf.keras.layers.Conv2D(32, 3, activation = 'relu', padding = "same"),
    tf.keras.layers.MaxPooling2D(pool_size = 2, padding = "same"),

    tf.keras.layers.Conv2D(16, 3, activation = 'relu', padding = "same"),
    tf.keras.layers.MaxPooling2D(pool_size = 2, padding = "same"),

    tf.keras.layers.Conv2D(8, 3, activation = 'relu', padding = "same"),
    tf.keras.layers.MaxPooling2D(pool_size = 2, padding = "same"),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(12, activation = "relu"),
    #tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense(4, activation = "softmax")
])

multiclassifier.compile(
    optimizer = keras.optimizers.Adam(1e-3),
    loss = "categorical_crossentropy",
    metrics = ["categorical_accuracy"])

multiclassifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 65, 65, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 33, 33, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 33, 33, 16)        4624
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 17, 17, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 17, 17, 8)         1160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 9, 9, 8)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 648)               0
# _________________________________________________________________
# dense (Dense)                (None, 12)                7788
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 52
# =================================================================
# Total params: 13,944
# Trainable params: 13,944
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = multiclassifier.fit(
    x = X_train, 
    y = y_train,
    epochs = epochs, 
    steps_per_epoch = steps_per_epoch, 
    
    validation_data = (X_test, y_test),
    callbacks = [tf.keras.callbacks.EarlyStopping(monitor = 'loss', patience = 3)])
# Out:
# Epoch 1/25
# 234/234 [==============================] - 113s 480ms/step - loss: 1.0094 - categorical_accuracy: 0.5818 - val_loss: 0.7039 - val_categorical_accuracy: 0.7203
# Epoch 2/25
# 234/234 [==============================] - 112s 479ms/step - loss: 0.6117 - categorical_accuracy: 0.7618 - val_loss: 0.5486 - val_categorical_accuracy: 0.7885
# Epoch 3/25
# 234/234 [==============================] - 111s 475ms/step - loss: 0.5284 - categorical_accuracy: 0.7954 - val_loss: 0.5121 - val_categorical_accuracy: 0.8010
# Epoch 4/25
# 234/234 [==============================] - 111s 474ms/step - loss: 0.4909 - categorical_accuracy: 0.8112 - val_loss: 0.4820 - val_categorical_accuracy: 0.8152
# Epoch 5/25
# 234/234 [==============================] - 111s 477ms/step - loss: 0.4672 - categorical_accuracy: 0.8203 - val_loss: 0.4652 - val_categorical_accuracy: 0.8228
# Epoch 6/25
# 234/234 [==============================] - 112s 479ms/step - loss: 0.4465 - categorical_accuracy: 0.8291 - val_loss: 0.4504 - val_categorical_accuracy: 0.8285
# Epoch 7/25
# 234/234 [==============================] - 112s 479ms/step - loss: 0.4312 - categorical_accuracy: 0.8356 - val_loss: 0.4573 - val_categorical_accuracy: 0.8285
# Epoch 8/25
# 234/234 [==============================] - 111s 473ms/step - loss: 0.4207 - categorical_accuracy: 0.8394 - val_loss: 0.4359 - val_categorical_accuracy: 0.8345
# Epoch 9/25
# 234/234 [==============================] - 112s 481ms/step - loss: 0.4074 - categorical_accuracy: 0.8449 - val_loss: 0.4305 - val_categorical_accuracy: 0.8381
# Epoch 10/25
# 234/234 [==============================] - 113s 483ms/step - loss: 0.4007 - categorical_accuracy: 0.8476 - val_loss: 0.4364 - val_categorical_accuracy: 0.8290
# Epoch 11/25
# 234/234 [==============================] - 112s 480ms/step - loss: 0.3911 - categorical_accuracy: 0.8516 - val_loss: 0.4217 - val_categorical_accuracy: 0.8422
# Epoch 12/25
# 234/234 [==============================] - 112s 481ms/step - loss: 0.3817 - categorical_accuracy: 0.8558 - val_loss: 0.4167 - val_categorical_accuracy: 0.8446
# Epoch 13/25
# 234/234 [==============================] - 112s 478ms/step - loss: 0.3771 - categorical_accuracy: 0.8573 - val_loss: 0.4264 - val_categorical_accuracy: 0.8416
# Epoch 14/25
# 234/234 [==============================] - 112s 478ms/step - loss: 0.3701 - categorical_accuracy: 0.8602 - val_loss: 0.4242 - val_categorical_accuracy: 0.8387
# Epoch 15/25
# 234/234 [==============================] - 111s 476ms/step - loss: 0.3663 - categorical_accuracy: 0.8619 - val_loss: 0.4078 - val_categorical_accuracy: 0.8495
# Epoch 16/25
# 234/234 [==============================] - 112s 479ms/step - loss: 0.3617 - categorical_accuracy: 0.8626 - val_loss: 0.4204 - val_categorical_accuracy: 0.8406
# Epoch 17/25
# 234/234 [==============================] - 112s 477ms/step - loss: 0.3559 - categorical_accuracy: 0.8663 - val_loss: 0.4047 - val_categorical_accuracy: 0.8515
# Epoch 18/25
# 234/234 [==============================] - 112s 478ms/step - loss: 0.3494 - categorical_accuracy: 0.8678 - val_loss: 0.4089 - val_categorical_accuracy: 0.8531
# Epoch 19/25
# 234/234 [==============================] - 111s 476ms/step - loss: 0.3485 - categorical_accuracy: 0.8687 - val_loss: 0.4049 - val_categorical_accuracy: 0.8488
# Epoch 20/25
# 234/234 [==============================] - 112s 478ms/step - loss: 0.3428 - categorical_accuracy: 0.8716 - val_loss: 0.4081 - val_categorical_accuracy: 0.8516
# Epoch 21/25
# 234/234 [==============================] - 112s 479ms/step - loss: 0.3385 - categorical_accuracy: 0.8736 - val_loss: 0.3998 - val_categorical_accuracy: 0.8551
# Epoch 22/25
# 234/234 [==============================] - 112s 480ms/step - loss: 0.3379 - categorical_accuracy: 0.8725 - val_loss: 0.4028 - val_categorical_accuracy: 0.8508
# Epoch 23/25
# 234/234 [==============================] - 112s 478ms/step - loss: 0.3316 - categorical_accuracy: 0.8760 - val_loss: 0.3970 - val_categorical_accuracy: 0.8587
# Epoch 24/25
# 234/234 [==============================] - 112s 480ms/step - loss: 0.3289 - categorical_accuracy: 0.8774 - val_loss: 0.3953 - val_categorical_accuracy: 0.8547
# Epoch 25/25
# 234/234 [==============================] - 112s 479ms/step - loss: 0.3261 - categorical_accuracy: 0.8775 - val_loss: 0.3948 - val_categorical_accuracy: 0.8568

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epoch = range(1, len(loss) + 1)
plt.plot(epoch, loss, 'y', label = 'Training loss')
plt.plot(epoch, val_loss, 'r', label = 'Validation loss')
plt.title('Training and validation loss for multi-classifier')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig(save_path + "multi-classifier-" + filename + "-loss_vs_epoch.png")
plt.show()

acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
plt.plot(epoch, acc, 'y', label = 'Training accuracy')
plt.plot(epoch, val_acc, 'r', label = 'Validation accuracy')
plt.title('Training and validation accuracy for multi-classifier')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig(save_path + "multi-classifier-" + filename + "-accuracy_vs_epoch.png")
plt.show()

# %%
#get actual metrics of train data
score_train = multiclassifier.evaluate(X_train, y_train)

#get actual metrics of test data
score_test = multiclassifier.evaluate(X_test, y_test)
# Out:
# 3000/3000 [==============================] - 39s 13ms/step - loss: 0.3140 - categorical_accuracy: 0.8828
# 750/750 [==============================] - 10s 13ms/step - loss: 0.3948 - categorical_accuracy: 0.8568

# %%
plt.bar(["train", "test"], 
        [score_train[1], score_test[1]],
        color =['red', 'blue'], width = 0.4)
 
plt.ylabel("Accuracy")
plt.title("multi-classifier accuracy train/test comparison")
plt.savefig(save_path + "multi-classifier-" + filename + "-train-test-accuracy.png")
plt.show()

# %%
plt.bar(["train", "test"], 
        [score_train[0], score_test[0]],
        color =['pink', 'turquoise'], width = 0.4)
 
plt.ylabel("loss")
plt.title("multi-classifier loss train/test comparison")
plt.savefig(save_path + "multi-classifier-" + filename + "-train-test-loss.png")
plt.show()

# %%
 multiclassifier.save(save_path + "multi-classifier-" + filename)
# Out:
# INFO:tensorflow:Assets written to: /tmp/qrcode/multi-classifier-30000-0.8-25-234-12/assets
